# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Cargar datos

# %%
df = pd.read_csv("dataset_final.csv", index_col=0)

# %%
df.head(2)
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# #
# 1     45           1      False
# 2     60           1      False

# %% [markdown]
#     1. ¿Cuántos pokémon hay en el dataset?

# %% [markdown]
# El dataset tiene 800 pokemon

# %%
df["Name"].unique
# Out:
# <bound method Series.unique of 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object>

# %% [markdown]
#     2. ¿Cuántos pokémon hay de tipo Poison? (Type 1)

# %% [markdown]
# Existen 28 tipos de pokemon tipo Poison

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
#     3. ¿Cuántos tipos diferentes de pokémon hay? (Type 1)

# %% [markdown]
# Existen 18 diferentes tipos de Pokemon tipo 1

# %%
df["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
#     2. ¿Cuántos pokémon hay de cada tipo? (Type 1)

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
#     2.1 ¿cual es el tipo de pokémon con más pokémon? (Type 1)

# %% [markdown]
# Del tipo 1 los pokemones predominantes son los de tipo Agua

# %% [markdown]
#     3. ¿Cuál es el pokémon más rápido?

# %% [markdown]
# Los pokemones más rapidos son los de velocidad de 180

# %%
df["Speed"]. max()
# Out:
# 180

# %%
Speed =df[df['Speed'].isin([180])]
Speed["Name"].unique()
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard',
#        'CharizardMega Charizard X', 'CharizardMega Charizard Y',
#        'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise',
#        'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna',
#        'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto',
#        'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow',
#        'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew',
#        'Sandslash', 'Nidoran♀', 'Nidorina', 'Nidoqueen', 'Nidoran♂',
#        'Nidorino', 'Nidoking', 'Clefairy', 'Clefable', 'Vulpix',
#        'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat',
#        'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect', 'Venonat',
#        'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian', 'Psyduck',
#        'Golduck', 'Mankey', 'Primeape', 'Growlithe', 'Arcanine',
# ...

# %% [markdown]
#     4. ¿Cuántos pokemon tiene una defensa superior a 100?

# %% [markdown]
# 123 pokemones tienen una defensa superior a 100

# %%
High_defense= df[df["Defense"]>100]

# %%
High_defense.count()
# Out:
# Name          123
# Type 1        123
# Type 2         87
# Total         123
# HP            123
# Attack        123
# Defense       123
# Sp. Atk       123
# Sp. Def       123
# Speed         123
# Generation    123
# Legendary     123
# dtype: int64

# %% [markdown]
#     4.1 ¿Cuántos pokemon tiene una defensa inferior a 100?

# %% [markdown]
# 644 tienen una defensa inferior a 100

# %%
low_defense= df[df["Defense"]<100]

# %%
low_defense.count()
# Out:
# Name          644
# Type 1        644
# Type 2        306
# Total         644
# HP            644
# Attack        644
# Defense       644
# Sp. Atk       644
# Sp. Def       644
# Speed         644
# Generation    644
# Legendary     644
# dtype: int64

# %% [markdown]
#     5. ¿Cuántos pokemon tiene una defensa superior a 100 y una velocidad superior a 100?

# %% [markdown]
# 123 pokemones tiene una defensa superior a 100 y una velocidad superior a 100

# %%
High_defense_speed= df.loc[(df.Defense > 100) & (df.Speed > 100),["Defense","Speed"]]

# %%
High_defense_speed.count()
# Out:
# Defense    123
# Speed      123
# dtype: int64

# %% [markdown]
#     6. Ordena el dataset por el tipo 1 y por el tipo 2

# %%
df.sort_values(by =["Type 1", "Type 2"])
# Out:
#                         Name Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 595                   Joltik    Bug  Electric    319   50      47       50
# 596               Galvantula    Bug  Electric    472   70      77       60
# 214                Heracross    Bug  Fighting    500   80     125       75
# 214  HeracrossMega Heracross    Bug  Fighting    600   80     185      115
# 636                 Larvesta    Bug      Fire    360   55      85       55
# ..                       ...    ...       ...    ...  ...     ...      ...
# 594                Alomomola  Water       NaN    470  165      75       80
# 656                  Froakie  Water       NaN    314   41      56       40
# 657                Frogadier  Water       NaN    405   54      63       52
# 692                Clauncher  Water       NaN    330   50      53       62
# 693                Clawitzer  Water       NaN    500   71      73       88
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
#     7. Crea un nuevo dataset con los pokémon de tipo Water y Fire como primer tipo

# %%
Water_Fire= df[(df["Type 1"]== "Water") | (df["Type 1"]== "Fire")]

# %%
Water_Fire
# Out:
#                           Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 4                   Charmander   Fire     NaN    309  39      52       43
# 5                   Charmeleon   Fire     NaN    405  58      64       58
# 6                    Charizard   Fire  Flying    534  78      84       78
# 6    CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6    CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# ..                         ...    ...     ...    ...  ..     ...      ...
# 667                     Litleo   Fire  Normal    369  62      50       58
# 668                     Pyroar   Fire  Normal    507  86      68       72
# 692                  Clauncher  Water     NaN    330  50      53       62
# 693                  Clawitzer  Water     NaN    500  71      73       88
# 721                  Volcanion   Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
#     8. Crea un nuevo dataset con los pokemon Legendary

# %%
Legendary= df[(df["Legendary"]== True)]

# %%
Legendary
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 719              Diancie      Rock     Fairy    600   50     100      150
# 719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 721            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %% [markdown]
#     9. Calcula el promedio de stats de los pokemon Legendary (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed) y los no Legendary

# %%
Legendary.describe()
# Out:
#             Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count   65.000000   65.000000   65.000000   65.000000   65.000000   65.000000
# mean   637.384615   92.738462  116.676923   99.661538  122.184615  105.938462
# std     60.937389   21.722164   30.348037   28.255131   31.104608   28.827004
# min    580.000000   50.000000   50.000000   20.000000   50.000000   20.000000
# 25%    580.000000   80.000000  100.000000   90.000000  100.000000   90.000000
# 50%    600.000000   91.000000  110.000000  100.000000  120.000000  100.000000
# 75%    680.000000  105.000000  131.000000  115.000000  150.000000  120.000000
# max    780.000000  150.000000  190.000000  200.000000  194.000000  200.000000
#
#        Speed  Generation
# count   65.0   65.000000
# mean   180.0    3.769231
# std      0.0    1.455262
# min    180.0    1.000000
# 25%    180.0    3.000000
# 50%    180.0    4.000000
# 75%    180.0    5.000000
# max    180.0    6.000000

# %%
Promedio_Legendary = Legendary.describe().loc['mean'][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
Promedio_Legendary
# Out:
# HP          92.738462
# Attack     116.676923
# Defense     99.661538
# Sp. Atk    122.184615
# Sp. Def    105.938462
# Speed      180.000000
# Name: mean, dtype: float64

# %%
No_legendary= df[(df["Legendary"]== False)]

# %%
Promedio_No_legendary = No_legendary.describe().loc['mean'][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
Promedio_No_legendary
# Out:
# HP          67.182313
# Attack      75.669388
# Defense     71.559184
# Sp. Atk     68.454422
# Sp. Def     68.892517
# Speed      180.000000
# Name: mean, dtype: float64

# %% [markdown]
#     10. Crea un nuevo dataframe con el resultado del anterior ejercicio comparando ambos promedios

# %%
New_dataframe= pd.DataFrame([Promedio_No_legendary, Promedio_Legendary], index=['No Legendary', 'Legendary'])
New_dataframe
# Out:
#                      HP      Attack    Defense     Sp. Atk     Sp. Def  Speed
# No Legendary  67.182313   75.669388  71.559184   68.454422   68.892517  180.0
# Legendary     92.738462  116.676923  99.661538  122.184615  105.938462  180.0

# %% [markdown]
#     11. Añade una nueva colunma ['Doble tipo'] al dataframe inicial que indique si el pokemon tiene dos tipos o no

# %%
df['Doble tipo'] = (df['Type 1'].notna()) & (df['Type 2'].notna())
df.head(5)
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Doble tipo
# #
# 1       65    180           1      False        True
# 2       80    180           1      False        True
# 3      100    180           1      False        True
# 3      120    180           1      False        True
# 4       50    180           1      False       False

# %% [markdown]
#     12. Muestra las columas Name, Type 1, Type 2 de los pokémon que tienen dos tipos y ordenalos por Type 1 , Type 2 y Name

# %%
Doble_tipo = df['Doble tipo'] == True
df[Doble_tipo].sort_values(['Type 1', 'Type 2', 'Name'])[['Type 1', 'Type 2','Name']]
# Out:
#     Type 1    Type 2                     Name
# #
# 596    Bug  Electric               Galvantula
# 595    Bug  Electric                   Joltik
# 214    Bug  Fighting                Heracross
# 214    Bug  Fighting  HeracrossMega Heracross
# 636    Bug      Fire                 Larvesta
# ..     ...       ...                      ...
# 565  Water      Rock               Carracosta
# 222  Water      Rock                  Corsola
# 369  Water      Rock                Relicanth
# 564  Water      Rock                 Tirtouga
# 395  Water     Steel                 Empoleon
#
# [414 rows x 3 columns]

# %%
from functools import reduce

'''
13. Dada una lista de Artículos con sus precio. Define las siguientes funciones:
Puedes definir más funciones si lo consideras necesario.
'''
articulos = {
    'Camisa': 20,
    'Pantalón': 30,
    'Calcetines': 5,
    'Zapatos': 50,
    'Gorra': 10,
    'Bufanda': 15,
    'Gafas': 25,
    'Reloj': 35,
    'Corbata': 40,
}

compra = ['Camisa', 'Pantalón', 'Pantalón', 'Gorra', 'Gafas', 'Corbata']

# %% [markdown]
#     Una función que calcule el precio total de la compra

# %%
def total_compra(articulos, compra):
    precios = list(map(lambda item: articulos.get(item), compra))
    return reduce(lambda prev, actual: prev + actual, precios)

# %% [markdown]
#     Una función que calcule el precio total de la compra con un descuento del 10

# %%
def descuento(articulos, compra):
    total = total_compra(articulos, compra)
    descuento = total * 0.1
    return total - descuento

# %% [markdown]
#     Una función que calcule el precio total de la compra con un descuento del 10% si la compra supera los 100€

# %%
def descuento_100(articulos, compra):
    if total_compra(articulos, compra) > 100:
        return descuento(articulos, compra)
    else:
        return total_compra(articulos, compra)

# %% [markdown]
#     Una función que calcule el precio total aplicando el IVA (21%)

# %%
def IVA(articulos, compra):
    total = total_compra(articulos, compra)
    impuesto = total * 0.21
    return total + impuesto

# %% [markdown]
#     lista los artículos cuyo precio es superior a 20€

# %%
def mayor_20(articulos):
    return list(filter(lambda articulo: articulos.get(articulo) > 20, articulos))

# %% [markdown]
#     14. Dada una lista de tuplas con el nombre de un alumno, apellidos, curso y sus notas.
#
#  Define una funcion que reciba el curso y saque una lista en la que aparezca e nombre y apellidos y el promedio de sus notas.
#  Puedes definir más funciones si lo consideras necesario.

# %%
alumnos = [('Juan', 'Pérez', '1', [5, 6, 7, 8, 9]),
            ('Ana', 'García', '2', [5, 6, 7, 8, 9]),
            ('Luis', 'González', '1', [5, 6, 7, 8, 9]),
            ('María', 'Martínez', '2', [5, 6, 7, 8, 9]),
            ('Pedro', 'Rodríguez', '1', [5, 6, 7, 8, 9]),
            ('Lucía', 'Hernández', '2', [5, 6, 7, 8, 9]),
            ('Marta', 'López', '1', [5, 6, 7, 8, 9]),
            ('Sara', 'Díaz', '2', [5, 6, 7, 8, 9]),
            ('Javier', 'Sánchez', '1', [5, 6, 7, 8, 9]),
            ('Miguel', 'Fernández', '2', [5, 6, 7, 8, 9]),
            ('Sergio', 'Jiménez', '1', [5, 6, 7, 8, 9]),
            ('Sandra', 'Ruiz', '2', [5, 6, 7, 8, 9]),
            ('Pablo', 'Álvarez', '1', [5, 6, 7, 8, 9]),
            ('María', 'Gómez', '2', [5, 6, 7, 8, 9]),
]

# %%
def notas_por_curso(curso, alumnos):
    lista_curso = []
    for i in range(len(alumnos)):
        if alumnos[i][2] == curso:
            nombre_y_apellido = (alumnos[i][0]+" "+alumnos[i][1])
            promedio = (sum(alumnos[i][3])/len(alumnos[i][3]))
            lista_curso.append((nombre_y_apellido, "Promedio: ", promedio))
    return lista_curso

# %%
notas_por_curso("1", alumnos)
# Out:
# [('Juan Pérez', 'Promedio: ', 7.0),
#  ('Luis González', 'Promedio: ', 7.0),
#  ('Pedro Rodríguez', 'Promedio: ', 7.0),
#  ('Marta López', 'Promedio: ', 7.0),
#  ('Javier Sánchez', 'Promedio: ', 7.0),
#  ('Sergio Jiménez', 'Promedio: ', 7.0),
#  ('Pablo Álvarez', 'Promedio: ', 7.0)]

# %%
notas_por_curso("2", alumnos)
# Out:
# [('Ana García', 'Promedio: ', 7.0),
#  ('María Martínez', 'Promedio: ', 7.0),
#  ('Lucía Hernández', 'Promedio: ', 7.0),
#  ('Sara Díaz', 'Promedio: ', 7.0),
#  ('Miguel Fernández', 'Promedio: ', 7.0),
#  ('Sandra Ruiz', 'Promedio: ', 7.0),
#  ('María Gómez', 'Promedio: ', 7.0)]
